# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
with open('for_loop_result.txt') as f:
    data = f.readlines()

# %%
string = ''.join(data)
data = string.split('\n')
data.pop()
data = np.array(data).reshape(8, 2)
data
# Out:
# array([['3.5.5 ', '0.01722473750123754'],
#        ['3.6.15', '0.015271460596704856'],
#        ['3.7.12', '0.0158845609'],
#        ['3.8.19', '0.0167226325'],
#        ['3.9.19', '0.0132897995'],
#        ['3.10.1', '0.013779836398316547'],
#        ['3.11.9', '0.013492449501063675'],
#        ['3.12.3', '0.013915394601644948']], dtype='<U20')

# %%
fig, ax = plt.subplots()
ax.plot(data[:,0], data[:,1].astype(float), 'o-')
ax.set(xlabel='Python version', ylabel='Time (s)',
         title='For loop performance (1e+5 iterations, average of 10 runs)')
ax.grid()
fig.savefig("for_loop_performance.png", transparent=False)
